# %% [markdown]
# <a href="https://colab.research.google.com/github/VyjayantiN/FMML-Projects-Assignments-2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 11:32:11--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   179MB/s    in 0.4s
#
# 2024-03-31 11:32:11 (179 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 37892   1103.2670v1  The estimation of asset return distributions i...  stat
# 21959   1007.2450v1  Distributions over permutations arise in appli...  stat
# 3958    0705.2516v1  The work proposes the application of neural ne...    cs
# 21728   1210.5806v1  Multi-task sparse feature learning aims to imp...  stat
# 22513  1610.06235v1  Independent component analysis (ICA) is a powe...  stat
# ...             ...                                                ...   ...
# 30347  1712.00250v3  Convolutional Neural Networks have made their ...    cs
# 21531   0911.0280v1  Inferring the causal structure of a set of ran...  stat
# 17958  cs/9712102v1  The assessment of bidirectional heuristic sear...    cs
# 29296  1709.00308v2  In recent years, deep learning (DL), a re-bran...    cs
# 36415   1401.2482v1  Affective multimedia documents such as images,...    cs
#
#                                                    title  year  \
# 37892  Constrained Mixture Models for Asset Returns M...  2011
# 21959             Directional Statistics on Permutations  2010
# 3958   Condition Monitoring of HV Bushings in the Pre...  2007
# 21728            Multi-Stage Multi-Task Feature Learning  2012
# 22513  Enhancing ICA Performance by Exploiting Sparsi...  2016
# ...                                                  ...   ...
# 30347  Learning Deep Representations for Word Spottin...  2017
# 21531  Causal Inference on Discrete Data using Additi...  2009
# 17958        Bidirectional Heuristic Search Reconsidered  1997
# 29296  A Comprehensive Survey of Deep Learning in Rem...  2017
# 36415  STIMONT: A core ontology for multimedia stimul...  2014
#
#                                                 keywords
# 37892  [estimation, distributions, determining, strat...
# 21959  [distributions, permutations, applications, in...
# 3958   [application, optimisation, algorithms, compen...
# 21728  [generalization, performance, exploiting, succ...
# 22513  [independent, component, separation, assumptio...
# ...                                                  ...
# 30347  [convolutional, performance, annotated, introd...
# 21531  [inferring, structure, variables, distribution...
# 17958  [assessment, bidirectional, heuristic, incorre...
# 29296  [recognition, processing, possesses, challenge...
# 36415  [affective, multimedia, documents, emotional, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 37892    [estimation, distributions, determining, strat...
# 21959    [distributions, permutations, applications, in...
# 3958     [application, optimisation, algorithms, compen...
# 21728    [generalization, performance, exploiting, succ...
# 22513    [independent, component, separation, assumptio...
#                                ...
# 19049    [literature, graphical, increased, attention, ...
# 13569    [resolution, unsupervised, reservoir, intercon...
# 26502    [compressed, discussed, separately, compressiv...
# 38324    [broadcast, effective, techniques, accessible,...
# 15460    [quantitative, geographically, preferred, coor...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8746 words.
# Out of those 4574 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a4aeced2-99ee-47eb-a05f-9c39acaa14e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4aeced2-99ee-47eb-a05f-9c39acaa14e6")) {                    Plotly.newPlot(                        "a4aeced2-99ee-47eb-a05f-9c39acaa14e6",                        [{"x":["maximisation","constrained","description","modelling","estimation","strategies","constraints","estimated","accounting","determining","expectation","distributions","framework","distribution","densities","continuous","definition","applications","representation","instances","permutation","demonstration","factorial","inference","embedding","difficulty","considered","multinomial","permutations","establishing","hypersphere","demonstrate","polynomial","projections","impractical","statistics","directional","probability","procedure","developed","efficiency","algorithms","compensate","simultaneously","conditions","computational","evolutionary","computing","condition","classifying","deteriorated","simulations","monitoring","classification","variables","application","optimisation","production","regularizer","reproducibility","approximating","suboptimal","biomedical","regularization","informatics","formulation","generalization","performance","formulated","exploiting","theoretical","interpretations","synthetic","parameter","including","successfully","comparison","algorithm","optimization","intuitive","effectiveness","empirical","convergence","incorporated","improvement","diversity","minimization","component","independence","independent","resulting","statistical","assumption","additionally","statistically","separation","exploitation","restrictive","important","resonance","information","functional","enhancing","available","demonstrated","constructs","ensembles","properties","evaluated","intensively","incorporate","regression","approaches","different","analytically","challenge","variational","functions","problematic","predictive","implementation","situations","likelihood","primarily","efficient","alternative","observation","illustrate","containing","approximations","hyperparameters","modifications","considers","posteriori","propagation","adaptively","improving","difficult","intractable","performed","computationally","iterative","expensive","electromagnetic","applicable","efficiently","frequencies","overlapping","contribution","simulation","methodology","afterwards","scattering","processing","generalized","especially","regularized","introducing","conventional","bottleneck","reflectivity","operational","parametric","interaction","introduce","microwave","transformation","typically","distributed","realistic","resolution","distinction","sometimes","mechanisms","combination","practical","something","investigate","treatment","conversely","perspective","ingrained","complement","developers","automatic","virtually","duplicate","community","structure","phenomena","dimensional","observational","electronic","education","personalized","quantitative","leveraged","recommendations","decisions","randomized"],"y":[2,55,67,57,178,104,158,58,8,35,35,109,554,176,11,98,32,407,375,98,6,12,2,191,111,45,107,6,4,13,1,577,54,25,14,55,22,166,112,188,172,570,12,122,132,269,62,132,40,39,2,58,35,498,128,234,20,21,20,3,25,14,13,77,2,70,104,870,43,76,155,6,131,110,231,79,157,799,318,31,217,164,117,27,156,44,69,101,26,127,141,168,62,72,24,22,15,5,369,24,710,43,16,282,103,18,10,195,141,1,73,106,414,768,14,178,55,235,6,49,135,42,57,24,390,97,70,73,52,27,7,16,48,10,85,27,95,139,29,119,89,76,62,3,44,143,19,23,75,82,63,6,8,303,68,123,35,43,115,11,2,19,32,93,336,2,70,97,101,62,109,4,33,48,153,140,15,147,26,6,69,2,14,9,193,4,6,95,340,27,202,4,20,10,18,63,7,24,53,23],"type":"bar"},{"x":["maximisation","constrained","descripti ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4574,), (4574, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.805

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <span style=''>of</span> <span style=''>Advanced</span> <span style=''>Record</span> <span style=''>Linkage</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Techniques</span> <span style=''>for</span> <span style=''>Complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Population</span> <span style='background-color:rgba(0, 255, 0, 0.4125874125874125);'>Reconstruction</span> <br/><br/><span style=''>Record</span> <span style=''>linkage</span> <span style=''>is</span> <span style=''>the</span> <span style=''>process</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>records</span> <span style=''>that</span> <span style=''>refer</span> <span style=''>to</span> <span style=''>the</span> <span style=''>same</span> <span style=''>entities</span> <span style=''>from</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.45238095238095233);'>databases</span> <span style=''>This</span> <span style=''>process</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.38992042440318303);'>challenging</span> <span style=''>because</span> <span style=''>commonly</span> <span style=''>no</span> <span style=''>unique</span> <span style=''>entity</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>identifiers</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>Linkage</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style=''>has</span> <span style=''>to</span> <span style=''>rely</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style='background-color:rgba(0, 255, 0, 0.32631578947368417);'>attributes</span> <span style=''>such</span> <span style=''>as</span> <span style=''>names</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>addresses</span> <span style=''>of</span> <span style=''>people</span> <span style=''>Recent</span> <span style=''>years</span> <span style=''>have</span> <span style=''>seen</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4827586206896551);'>development</span> <span style=''>of</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>for</span> <span style=''>linking</span> <span style=''>data</span> <span style=''>from</span> <span style=''>diverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>areas</span> <span style=''>where</span> <span style=''>a</span> <span style=''>major</span> <span style=''>focus</span> <span style=''>has</span> <span style=''>been</span> <span style=''>on</span> <span style=''>linking</span> <span style=''>complex</span> <span style=''>data</span> <span style=''>that</span> <span style=''>contain</span> <span style=''>records</span> <span style=''>about</span> <span style='background-color:rgba(0, 255, 0, 0.3379790940766551);'>different</span> <span style=''>types</span> <span style=''>of</span> <span style=''>entities</span> <span style=''>Advanced</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>that</span> <span style=''>exploit</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>between</span> <span style=''>record</span> <span style='background-color:rgba(0, 255, 0, 0.32631578947368417);'>attributes</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifiability</span> <span style=''>of</span> <span style=''>l</span> <span style=''>1</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style=''>and</span> <span style=''>almost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>from</span> <span style=''>N</span> <span style=''>signals</span> <span style=''>mathbf</span> <span style=''>x</span> <span style=''>iin</span> <span style=''>mathbb</span> <span style=''>RK</span> <span style=''>for</span> <span style=''>i1N</span> <span style=''>via</span> <span style=''>l</span> <span style=''>1</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>We</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>mathbf</span> <span style=''>x</span> <span style=''>is</span> <span style=''>are</span> <span style=''>iid</span> <span style=''>random</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>K</span> <span style=''>columns</span> <span style=''>from</span> <span style=''>a</span> <span style=''>complete</span> <span style=''>(ie</span> <span style=''>square</span> <span style=''>and</span> <span style=''>invertible)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>mathbf</span> <span style=''>D</span> <span style=''>0</span> <span style=''>in</span> <span style=''>mathbb</span> <span style=''>RKtimes</span> <span style=''>K</span> <span style=''>Here</span> <span style=''>the</span> <span style=''>random</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficients</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>from</span> <span style=''>either</span> <span style=''>the</span> <span style=''>s</span> <span style=''>sparse</span> <span style=''>Gaussian</span> <span style=''>model</span> <span style=''>or</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bernoulli</span> <span style=''>Gaussian</span> <span style=''>model</span> <span style=''>First</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style=''>case</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style=''>and</span> <span style=''>almost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>mathbf</span> <span style=''>D</span> <span style=''>0</span> <span style=''>to</span> <span style=''>be</span> <span style=''>locally</span> <span style='background-c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>Learning</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.34814814814814815);'>Distribution</span> <span style=''>Free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <br/><br/><span style=''>We</span> <span style=''>develop</span> <span style=''>an</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>in</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>large</span> <span style=''>andor</span> <span style='background-color:rgba(255, 0, 0, 0.3714285714285715);'>streaming</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>approach</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.5897435897435896);'>covariance</span> <span style=''>fitting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictor</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desirable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.34814814814814815);'>distribution</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>It</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.37777777777777777);'>implemented</span> <span style=''>online</span> <span style=''>with</span> <span style=''>a</span> <span style=''>runtime</span> <span style=''>that</span> <span style=''>scales</span> <span style=''>linearly</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>has</span> <span style=''>a</span> <span style=''>constant</span> <span style=''>memory</span> <span style='background-color:rgba(0, 255, 0, 0.3953488372093023);'>requirement</span> <span style=''>avoids</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>prunes</span> <span style=''>away</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>redundant</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensions</span> <span style=''>without</span> <span style=''>relying</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>restrictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumptions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.34814814814814815);'>distribution</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.49999999999999994);'>conjunction</span> <span style=''>with</span> <span style=''>the</span> <span style=''>split</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>conformal</span> <span style=''>approach</span> <span style=''>it</span> <span style=''>also</span> <span style=''>produces</span> <span style='background-color:rgba(255, 0, 0, 0.34814814814814815);'>distribution</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>pr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>Sparse</span> <span style=''>Blind</span> <span style=''>Source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separation</span> <br/><br/><span style=''>Blind</span> <span style=''>Source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separation</span> <span style=''>is</span> <span style=''>a</span> <span style=''>widely</span> <span style=''>used</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>to</span> <span style=''>analyze</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multichannel</span> <span style=''>data</span> <span style=''>In</span> <span style=''>many</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>its</span> <span style=''>results</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>hampered</span> <span style=''>by</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>unknown</span> <span style=''>outliers</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>coined</span> <span style=''>rGMCA</span> <span style=''>(robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Morphological</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Analysis)</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>to</span> <span style=''>retrieve</span> <span style=''>sparse</span> <span style=''>sources</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>outliers</span> <span style=''>It</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explicitly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>the</span> <span style=''>sources</span> <span style=''>the</span> <span style=''>mixing</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>the</span> <span style=''>outliers</span> <span style=''>It</span> <span style=''>also</span> <span style=''>takes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>outliers</span> <span style=''>to</span> <span style=''>further</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>weighting</span> <span style=''>scheme</span> <span style=''>which</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>highly</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>rGMCA</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>mixing</span> <span style=''>matrix</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>with</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08360014229811455)
# 	knowledge (0.12379935965848453)
# 	representation (0.13340448239060831)
# 	segmentation (0.07186054784774101)
# 	processing (0.10779082177161152)
# 	detection (0.12451085023123444)
# 	information (0.25257915332621844)
# 	different (0.27321237993596587)
# 	recognition (0.1223763785129847)
# 	convolutional (0.14194236926360726)
#
# Some Statistics words are:
# 	stochastic (0.1412770236299648)
# 	algorithms (0.2961287078934138)
# 	statistical (0.15887380593262945)
# 	theoretical (0.15887380593262945)
# 	algorithm (0.3961789844142785)
# 	estimation (0.18099547511312217)
# 	distribution (0.1830065359477124)
# 	dimensional (0.19306184012066366)
# 	inference (0.21166415284062343)
# 	regression (0.18501759678230267)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ac3a6ba8-d901-4f8f-a121-5a83bcc960e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac3a6ba8-d901-4f8f-a121-5a83bcc960e8")) {                    Plotly.newPlot(                        "ac3a6ba8-d901-4f8f-a121-5a83bcc960e8",                        [{"x":["maximisation","constrained","description","modelling","estimation","strategies","constraints","estimated","accounting","determining","expectation","distributions","framework","distribution","densities","continuous","definition","applications","representation","instances","permutation","demonstration","factorial","inference","embedding","difficulty","considered","multinomial","permutations","establishing","hypersphere","demonstrate","polynomial","projections","impractical","statistics","directional","probability","procedure","developed","efficiency","algorithms","compensate","simultaneously","conditions","computational","evolutionary","computing","condition","classifying","deteriorated","simulations","monitoring","classification","variables","application","optimisation","production","regularizer","reproducibility","approximating","suboptimal","biomedical","regularization","informatics","formulation","generalization","performance","formulated","exploiting","theoretical","interpretations","synthetic","parameter","including","successfully","comparison","algorithm","optimization","intuitive","effectiveness","empirical","convergence","incorporated","improvement","diversity","minimization","component","independence","independent","resulting","statistical","assumption","additionally","statistically","separation","exploitation","restrictive","important","resonance","information","functional","enhancing","available","demonstrated","constructs","ensembles","properties","evaluated","intensively","incorporate","regression","approaches","different","analytically","challenge","variational","functions","problematic","predictive","implementation","situations","likelihood","primarily","efficient","alternative","observation","illustrate","containing","approximations","hyperparameters","modifications","considers","posteriori","propagation","adaptively","improving","difficult","intractable","performed","computationally","iterative","expensive","electromagnetic","applicable","efficiently","frequencies","overlapping","contribution","simulation","methodology","afterwards","scattering","processing","generalized","especially","regularized","introducing","conventional","bottleneck","reflectivity","operational","parametric","interaction","introduce","microwave","transformation","typically","distributed","realistic","resolution","distinction","sometimes","mechanisms","combination","practical","something","investigate","treatment","conversely","perspective","ingrained","complement","developers","automatic","virtually","duplicate","community","structure","phenomena","dimensional","observational","electronic","education","personalized","quantitative","leveraged","recommendations","decisions","randomized","estimating","heterogeneous","promising","published","dimensions","experiments","individually","significant","identifying","iterating","introduced","considering","exploited","performances","simultaneous","optimizing","interpreted","numerical","advantage","intensive","theoretically","alternatively","conceptually","screening","diagnosis","generally","clinicians","potential","suffering","consequently","minimally","disability","population","developmental","developing","individual","clinically","durations","technologies","demonstrations","methodologies","artificial","appealing","individuals","contemporary","classrooms","intelligence","extensive","literature","technology","intervention","acceptability"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	refitting
# 	contamination
# 	uncontaminated
# 	reassignment
# 	parameterizes
# 	unbalancedness
# 	blockmodel
# 	hemoglobin
# 	individualized
# 	controversial
# 	katehakis
# 	misspecification
# 	coregionalization
# 	definiteness
# 	symmetrization
# 	illustrations
# 	ellipsoidal
# 	textitfixed
# 	rewritten
# 	resembles
# Some words which never appear in Statistics papers:
# 	deteriorated
# 	electromagnetic
# 	something
# 	ingrained
# 	classrooms
# 	acceptability
# 	templates
# 	revelation
# 	lemmatization
# 	morphologically
# 	proliferation
# 	generations
# 	deceptive
# 	detections
# 	kinematic
# 	incapable
# 	concatenation
# 	complication
# 	newspaper
# 	surpassing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0596010280259455e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
